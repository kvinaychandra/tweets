# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:powderblue;
#            color:Black;
#            font-family:cursive
#            ">
# <h1 style="text-align:center;font-weight: bold">Twitter Sentiment Analysis With SVM, Naive Bayes, Bagging, Random Forest, And LSTM  </h1>
#
# </div>
# <p><img src = "https://www.vshsolutions.com/wp-content/uploads/2019/02/airlines.jpeg"  ></p>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:powderblue;
#            color:Black;
#            font-family:cursive
#            ">
# <h1 style="text-align:center;font-weight: bold"> Importing Libraries </h1>
# </div>

# %%
import pandas as pd
import seaborn as sns
import re, nltk
nltk.download('punkt')
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from matplotlib import pyplot
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score, accuracy_score
import string
from nltk.corpus import stopwords
nltk.download('stopwords')
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.metrics import f1_score
plt.style.use('fivethirtyeight')
plt.style.use('dark_background')
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from lime import lime_tabular
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.layers import Dense, Dropout
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 2022-01-06 07:19:25.890915: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
df =pd.read_csv(r'../input/twitter-airline-sentiment/Tweets.csv')
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
# Unique values of sentiment
df['airline_sentiment'].unique()
# Out:
# array(['neutral', 'positive', 'negative'], dtype=object)

# %%
# Unique values of sentiment plot

ax = sns.countplot(x="airline_sentiment", data=df)

# %% [markdown]
# > Positive and neutral tweets are almost equal.
#
# > Negative tweets are more than double of neutral or positive sentiments.

# %%
# Unique values of airline

plt.figure(figsize=(10,10))
ax = sns.countplot(x="airline", data=df)

# %% [markdown]
# > United has the most number of flights.
#
# > Virgin America has the least.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:powderblue;
#            color:Black;
#            font-family:cursive
#            ">
# <h1 style="text-align:center;font-weight: bold"> Utility Functions </h1>
# </div>

# %%
# I am tokenizing the tweet and also taking tokens from second index onwards as initital to gives airline name and '@' and lowering thm and later making it back a sentence
def clean_the_tweet(text):
  tokens= nltk.word_tokenize(re.sub("[^a-zA-Z]", " ",text))
  tokens = [token.lower() for token in tokens]
  return ' '.join(tokens[2:])

                 

def text_process(msg):
  nopunc =[char for char in msg if char not in string.punctuation]
  nopunc=''.join(nopunc)
  return ' '.join([word for word in nopunc.split() if word.lower() not in stopwords.words('english')])


 
def check_scores(clf,X_train, X_test, y_train, y_test):

  model=clf.fit(X_train, y_train)
  predicted_class=model.predict(X_test)
  predicted_class_train=model.predict(X_train)
  test_probs = model.predict_proba(X_test)
  test_probs = test_probs[:, 1]
  yhat = model.predict(X_test)
  lr_precision, lr_recall, _ = precision_recall_curve(y_test, test_probs)
  lr_f1, lr_auc = f1_score(y_test, yhat), auc(lr_recall, lr_precision)


  print('Train confusion matrix is: ',)
  print(confusion_matrix(y_train, predicted_class_train))

  print()
  print('Test confusion matrix is: ')
  print(confusion_matrix(y_test, predicted_class))
  print()
  print(classification_report(y_test,predicted_class)) 
  print() 
  train_accuracy = accuracy_score(y_train,predicted_class_train)
  test_accuracy = accuracy_score(y_test,predicted_class)

  print("Train accuracy score: ", train_accuracy)
  print("Test accuracy score: ",test_accuracy )
  print()
  train_auc = roc_auc_score(y_train, clf.predict_proba(X_train)[:,1])
  test_auc = roc_auc_score(y_test, clf.predict_proba(X_test)[:,1])

  print("Train ROC-AUC score: ", train_auc)
  print("Test ROC-AUC score: ", test_auc)
  fig, (ax1, ax2) = plt.subplots(1, 2)

  ax1.plot(lr_recall, lr_precision)
  ax1.set(xlabel="Recall", ylabel="Precision")

  plt.subplots_adjust(left=0.5,
                    bottom=0.1, 
                    right=1.5, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
  print()
  print('Are under Precision-Recall curve:', lr_f1)
  
  fpr, tpr, _ = roc_curve(y_test, test_probs)


  ax2.plot(fpr, tpr)
  ax2.set(xlabel='False Positive Rate', ylabel='True Positive Rate')

  print("Area under ROC-AUC:", lr_auc)
  return train_accuracy, test_accuracy, train_auc, test_auc



def grid_search(model, parameters, X_train, Y_train):
  #Doing a grid
  grid = GridSearchCV(estimator=model,
                       param_grid = parameters,
                       cv = 2, verbose=2, scoring='roc_auc')
  #Fitting the grid 
  grid.fit(X_train,Y_train)
  print()
  print()
  # Best model found using grid search
  optimal_model = grid.best_estimator_
  print('Best parameters are: ')
  print( grid.best_params_)

  return optimal_model

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:powderblue;
#            color:Black;
#            font-family:cursive
#            ">
# <h1 style="text-align:center;font-weight: bold"> Text Preparation </h1>
# </div>

# %%
# removing neutral tweets

df = df[df['airline_sentiment']!='neutral']
df['cleaned_tweet'] = df['text'].apply(clean_the_tweet)

df.head()
df['airline_sentiment'] = df['airline_sentiment'].apply(lambda x: 1 if x =='positive' else 0)
df.head()
# Out:
#              tweet_id  airline_sentiment  airline_sentiment_confidence  \
# 1  570301130888122368                  1                        0.3486
# 3  570301031407624196                  0                        1.0000
# 4  570300817074462722                  0                        1.0000
# 5  570300767074181121                  0                        1.0000
# 6  570300616901320704                  1                        0.6745
#
#   negativereason  negativereason_confidence         airline  \
# 1            NaN                     0.0000  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
# 5     Can't Tell                     0.6842  Virgin America
# 6            NaN                     0.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 1                    NaN    jnardino                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
# 5                    NaN    jnardino                 NaN              0
# 6                    NaN  cjmcginnis                 NaN              0
#
#                                                 text tweet_coord  \
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
# 5  @VirginAmerica seriously would pay $30 a fligh...         NaN
# 6  @VirginAmerica yes, nearly every time I fly VX...         NaN
#
#                tweet_created    tweet_location               user_timezone  \
# 1  2015-02-24 11:15:59 -0800               NaN  Pacific Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800               NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800               NaN  Pacific Time (US & Canada)
# 5  2015-02-24 11:14:33 -0800               NaN  Pacific Time (US & Canada)
# 6  2015-02-24 11:13:57 -0800  San Francisco CA  Pacific Time (US & Canada)
#
#                                        cleaned_tweet
# 1   you ve added commercials to the experience tacky
# 3  s really aggressive to blast obnoxious enterta...
# 4               it s a really big bad thing about it
# 5  would pay a flight for seats that didn t have ...
# 6  nearly every time i fly vx this ear worm won t...

# %%
# Cleaning the tweets, removing punctuation marks
df['cleaned_tweet'] = df['cleaned_tweet'].apply(text_process)
df.reset_index(drop=True, inplace = True)
df.head()
# Out:
#              tweet_id  airline_sentiment  airline_sentiment_confidence  \
# 0  570301130888122368                  1                        0.3486
# 1  570301031407624196                  0                        1.0000
# 2  570300817074462722                  0                        1.0000
# 3  570300767074181121                  0                        1.0000
# 4  570300616901320704                  1                        0.6745
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                     0.0000  Virgin America
# 1     Bad Flight                     0.7033  Virgin America
# 2     Can't Tell                     1.0000  Virgin America
# 3     Can't Tell                     0.6842  Virgin America
# 4            NaN                     0.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN    jnardino                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN    jnardino                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN  cjmcginnis                 NaN              0
#
#                                                 text tweet_coord  \
# 0  @VirginAmerica plus you've added commercials t...         NaN
# 1  @VirginAmerica it's really aggressive to blast...         NaN
# 2  @VirginAmerica and it's a really big bad thing...         NaN
# 3  @VirginAmerica seriously would pay $30 a fligh...         NaN
# 4  @VirginAmerica yes, nearly every time I fly VX...         NaN
#
#                tweet_created    tweet_location               user_timezone  \
# 0  2015-02-24 11:15:59 -0800               NaN  Pacific Time (US & Canada)
# 1  2015-02-24 11:15:36 -0800               NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:14:45 -0800               NaN  Pacific Time (US & Canada)
# 3  2015-02-24 11:14:33 -0800               NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:13:57 -0800  San Francisco CA  Pacific Time (US & Canada)
#
#                                        cleaned_tweet
# 0                 added commercials experience tacky
# 1  really aggressive blast obnoxious entertainmen...
# 2                               really big bad thing
# 3  would pay flight seats playing really bad thin...
# 4          nearly every time fly vx ear worm go away

# %%
df['airline_sentiment'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:powderblue;
#            color:Black;
#            font-family:cursive
#            ">
# <h1 style="text-align:center;font-weight: bold"> Base SVM model with TF-IDF </h1>
# </div>

# %%
# Creating object of TF-IDF vectorizer
vectorizer = TfidfVectorizer(use_idf=True, lowercase=True)
X_tf_idf= vectorizer.fit_transform(df.cleaned_tweet)
x_train, x_test, y_train, y_test = train_test_split(X_tf_idf, df['airline_sentiment'], random_state=42)

# %%
SVM = svm.SVC( probability=True)
s_train_accuracy, s_test_accuracy, s_train_auc, s_test_auc = check_scores(SVM,x_train, x_test, y_train, y_test)
# Out:
# Train confusion matrix is:
# [[6824   31]
#  [ 151 1649]]
#
# Test confusion matrix is:
# [[2291   32]
#  [ 296  267]]
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.93      2323
#            1       0.89      0.47      0.62       563
#
#     accuracy                           0.89      2886
#    macro avg       0.89      0.73      0.78      2886
# weighted avg       0.89      0.89      0.87      2886
#
#
# Train accuracy score:  0.9789716926632005
# Test accuracy score:  0.8863478863478863
#
# Train ROC-AUC score:  0.9969059080962801
# Test ROC-AUC score:  0.929176839222265
#
# Are under Precision-Recall curve: 0.6194895591647333
# Area under ROC-AUC: 0.8049817790703035

# %% [markdown]
# > With increase in FPR, TPR also increases.
#
# > With increase in recall, precision decreases.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:powderblue;
#            color:Black;
#            font-family:cursive
#            ">
# <h1 style="text-align:center;font-weight: bold"> After optimizing the hyperparameters with TF-IDF </h1>
# </div>

# %%
# Tuning the hyperparameters
parameters ={
    "C":[0.1,1,10],
    "kernel":['linear', 'rbf', 'sigmoid'],
    "gamma":['scale', 'auto']
}



svm_optimal = grid_search(svm.SVC(probability=True), parameters,x_train, y_train)
# Out:
# Fitting 2 folds for each of 18 candidates, totalling 36 fits
# [CV] C=0.1, gamma=scale, kernel=linear ...............................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................ C=0.1, gamma=scale, kernel=linear, total=   5.4s
# [CV] C=0.1, gamma=scale, kernel=linear ...............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    5.4s remaining:    0.0s
# [CV] ................ C=0.1, gamma=scale, kernel=linear, total=   5.3s
# [CV] C=0.1, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=0.1, gamma=scale, kernel=rbf, total=   8.8s
# [CV] C=0.1, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=0.1, gamma=scale, kernel=rbf, total=   8.4s
# [CV] C=0.1, gamma=scale, kernel=sigmoid ..............................
# [CV] ............... C=0.1, gamma=scale, kernel=sigmoid, total=   5.4s
# [CV] C=0.1, gamma=scale, kernel=sigmoid ..............................
# [CV] ............... C=0.1, gamma=scale, kernel=sigmoid, total=   5.3s
# [CV] C=0.1, gamma=auto, kernel=linear ................................
# [CV] ................. C=0.1, gamma=auto, kernel=linear, total=   5.4s
# [CV] C=0.1, gamma=auto, kernel=linear ................................
# [CV] ................. C=0.1, gamma=auto, kernel=linear, total=   5.0s
# [CV] C=0.1, gamma=auto, kernel=rbf ...................................
# [CV] .................... C=0.1, gamma=auto, kernel=rbf, total=   4.4s
# [CV] C=0.1, gamma=auto, kernel=rbf ...................................
# [CV] .................... C=0.1, gamma=auto, kernel=rbf, total=   4.2s
# [CV] C=0.1, gamma=auto, kernel=sigmoid ...............................
# [CV] ................ C=0.1, gamma=auto, kernel=sigmoid, total=   3.8s
# [CV] C=0.1, gamma=auto, kernel=sigmoid ...............................
# [CV] ................ C=0.1, gamma=auto, kernel=sigmoid, total=   3.9s
# [CV] C=1, gamma=scale, kernel=linear .................................
# [CV] .................. C=1, gamma=scale, kernel=linear, total=   5.1s
# [CV] C=1, gamma=scale, kernel=linear .................................
# [CV] .................. C=1, gamma=scale, kernel=linear, total=   5.4s
# [CV] C=1, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=1, gamma=scale, kernel=rbf, total=   9.7s
# [CV] C=1, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=1, gamma=scale, kernel=rbf, total=   9.3s
# [CV] C=1, gamma=scale, kernel=sigmoid ................................
# [CV] ................. C=1, gamma=scale, kernel=sigmoid, total=   5.0s
# [CV] C=1, gamma=scale, kernel=sigmoid ................................
# [CV] ................. C=1, gamma=scale, kernel=sigmoid, total=   4.7s
# [CV] C=1, gamma=auto, kernel=linear ..................................
# [CV] ................... C=1, gamma=auto, kernel=linear, total=   5.5s
# [CV] C=1, gamma=auto, kernel=linear ..................................
# [CV] ................... C=1, gamma=auto, kernel=linear, total=   4.9s
# [CV] C=1, gamma=auto, kernel=rbf .....................................
# [CV] ...................... C=1, gamma=auto, kernel=rbf, total=   4.6s
# [CV] C=1, gamma=auto, kernel=rbf .....................................
# [CV] ...................... C=1, gamma=auto, kernel=rbf, total=   4.4s
# [CV] C=1, gamma=auto, kernel=sigmoid .................................
# [CV] .................. C=1, gamma=auto, kernel=sigmoid, total=   3.9s
# [CV] C=1, gamma=auto, kernel=sigmoid .................................
# [CV] .................. C=1, gamma=auto, kernel=sigmoid, total=   4.1s
# [CV] C=10, gamma=scale, kernel=linear ................................
# [CV] ................. C=10, gamma=scale, kernel=linear, total=   5.4s
# [CV] C=10, gamma=scale, kernel=linear ................................
# [CV] ................. C=10, gamma=scale, kernel=linear, total=   5.7s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] .................... C=10, gamma=scale, kernel=rbf, total=  10.5s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] .................... C=10, gamma=scale, kernel=rbf, total=  10.3s
# [CV] C=10, gamma=scale, kernel=sigmoid ...............................
# [CV] ................ C=10, gamma=scale, kernel=sigmoid, total=   6.3s
# [CV] C=10, gamma=scale, kernel=sigmoid ...............................
# [CV] ................ C=10, gamma=scale, kernel=sigmoid, total=   7.0s
# [CV] C=10, gamma=auto, kernel=linear .................................
# [CV] .................. C=10, gamma=auto, kernel=linear, total=   5.3s
# [CV] C=10, gamma=auto, kernel=linear .................................
# [CV] .................. C=10, gamma=auto, kernel=linear, total=   5.5s
# [CV] C=10, gamma=auto, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=auto, kernel=rbf, total=   5.5s
# [CV] C=10, gamma=auto, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=auto, kernel=rbf, total=   5.7s
# [CV] C=10, gamma=auto, kernel=sigmoid ................................
# [CV] ................. C=10, gamma=auto, kernel=sigmoid, total=   4.8s
# [CV] C=10, gamma=auto, kernel=sigmoid ................................
# [CV] ................. C=10, gamma=auto, kernel=sigmoid, total=   4.7s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:  3.5min finished
# Best parameters are:
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
so_train_accuracy, so_test_accuracy, so_train_auc, so_test_auc = check_scores(svm_optimal,x_train, x_test, y_train, y_test)
# Out:
# Train confusion matrix is:
# [[6829   26]
#  [   5 1795]]
#
# Test confusion matrix is:
# [[2272   51]
#  [ 245  318]]
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      2323
#            1       0.86      0.56      0.68       563
#
#     accuracy                           0.90      2886
#    macro avg       0.88      0.77      0.81      2886
# weighted avg       0.89      0.90      0.89      2886
#
#
# Train accuracy score:  0.996418255343732
# Test accuracy score:  0.8974358974358975
#
# Train ROC-AUC score:  0.9987310154793744
# Test ROC-AUC score:  0.9287425383205553
#
# Are under Precision-Recall curve: 0.6824034334763949
# Area under ROC-AUC: 0.8075544315636269

# %% [markdown]
# > With increase in recall, preciison decreases which makes sense also.
#
# > With increase in TPR, FPR inceases.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:powderblue;
#            color:Black;
#            font-family:cursive
#            ">
# <h1 style="text-align:center;font-weight: bold"> Using Multinomial Naive Bayes </h1>
# </div>

# %%
m_train_accuracy, m_test_accuracy, m_train_auc, m_test_auc = check_scores(MultinomialNB(),x_train, x_test, y_train, y_test)
# Out:
# Train confusion matrix is:
# [[6853    2]
#  [1296  504]]
#
# Test confusion matrix is:
# [[2318    5]
#  [ 474   89]]
#
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91      2323
#            1       0.95      0.16      0.27       563
#
#     accuracy                           0.83      2886
#    macro avg       0.89      0.58      0.59      2886
# weighted avg       0.85      0.83      0.78      2886
#
#
# Train accuracy score:  0.8500288850375506
# Test accuracy score:  0.834026334026334
#
# Train ROC-AUC score:  0.9561105438041981
# Test ROC-AUC score:  0.9013005324009118
#
# Are under Precision-Recall curve: 0.2709284627092846
# Area under ROC-AUC: 0.7374839454006489

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:powderblue;
#            color:Black;
#            font-family:cursive
#            ">
# <h1 style="text-align:center;font-weight: bold"> Using Gaussian Naive Bayes
#  </h1>
# </div>

# %%
g_train_accuracy, g_test_accuracy, g_train_auc, g_test_auc=check_scores(GaussianNB(),x_train.toarray(), x_test.toarray(), y_train, y_test)
# Out:
# Train confusion matrix is:
# [[5543 1312]
#  [   0 1800]]
#
# Test confusion matrix is:
# [[1623  700]
#  [ 181  382]]
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.70      0.79      2323
#            1       0.35      0.68      0.46       563
#
#     accuracy                           0.69      2886
#    macro avg       0.63      0.69      0.63      2886
# weighted avg       0.79      0.69      0.72      2886
#
#
# Train accuracy score:  0.8484113229347198
# Test accuracy score:  0.6947331947331947
#
# Train ROC-AUC score:  0.9043034281546316
# Test ROC-AUC score:  0.688586755810495
#
# Are under Precision-Recall curve: 0.4644376899696049
# Area under ROC-AUC: 0.5471372315951626

# %% [markdown]
# > It is interesting to see in Naive Bayes, we are getting linear relationship.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:powderblue;
#            color:Black;
#            font-family:cursive
#            ">
# <h1 style="text-align:center;font-weight: bold"> Using AdaBoost
#  </h1>
# </div>

# %% [markdown]
# > **base estimator here is: decision stump**

# %%
a_train_accuracy, a_test_accuracy, a_train_auc, a_test_auc=check_scores(AdaBoostClassifier(),x_train,x_test, y_train, y_test)
# Out:
# Train confusion matrix is:
# [[6655  200]
#  [1012  788]]
#
# Test confusion matrix is:
# [[2251   72]
#  [ 328  235]]
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      2323
#            1       0.77      0.42      0.54       563
#
#     accuracy                           0.86      2886
#    macro avg       0.82      0.69      0.73      2886
# weighted avg       0.85      0.86      0.84      2886
#
#
# Train accuracy score:  0.8599653379549393
# Test accuracy score:  0.8613998613998614
#
# Train ROC-AUC score:  0.8689482940270687
# Test ROC-AUC score:  0.8373803091947158
#
# Are under Precision-Recall curve: 0.5402298850574713
# Area under ROC-AUC: 0.6298876361965743

# %%
params = {'n_estimators': [10, 50, 100, 500],
 'learning_rate': [0.0001, 0.001, 0.01, 0.1, 1.0],
 'algorithm': ['SAMME', 'SAMME.R']}

ada_optimal_model = grid_search(AdaBoostClassifier(), params,x_train, y_train)
# Out:
# Fitting 2 folds for each of 40 candidates, totalling 80 fits
# [CV] algorithm=SAMME, learning_rate=0.0001, n_estimators=10 ..........
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  algorithm=SAMME, learning_rate=0.0001, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME, learning_rate=0.0001, n_estimators=10 ..........
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  algorithm=SAMME, learning_rate=0.0001, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME, learning_rate=0.0001, n_estimators=50 ..........
# [CV]  algorithm=SAMME, learning_rate=0.0001, n_estimators=50, total=   1.1s
# [CV] algorithm=SAMME, learning_rate=0.0001, n_estimators=50 ..........
# [CV]  algorithm=SAMME, learning_rate=0.0001, n_estimators=50, total=   1.1s
# [CV] algorithm=SAMME, learning_rate=0.0001, n_estimators=100 .........
# [CV]  algorithm=SAMME, learning_rate=0.0001, n_estimators=100, total=   2.3s
# [CV] algorithm=SAMME, learning_rate=0.0001, n_estimators=100 .........
# [CV]  algorithm=SAMME, learning_rate=0.0001, n_estimators=100, total=   2.7s
# [CV] algorithm=SAMME, learning_rate=0.0001, n_estimators=500 .........
# [CV]  algorithm=SAMME, learning_rate=0.0001, n_estimators=500, total=  11.6s
# [CV] algorithm=SAMME, learning_rate=0.0001, n_estimators=500 .........
# [CV]  algorithm=SAMME, learning_rate=0.0001, n_estimators=500, total=  12.1s
# [CV] algorithm=SAMME, learning_rate=0.001, n_estimators=10 ...........
# [CV]  algorithm=SAMME, learning_rate=0.001, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME, learning_rate=0.001, n_estimators=10 ...........
# [CV]  algorithm=SAMME, learning_rate=0.001, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME, learning_rate=0.001, n_estimators=50 ...........
# [CV]  algorithm=SAMME, learning_rate=0.001, n_estimators=50, total=   1.1s
# [CV] algorithm=SAMME, learning_rate=0.001, n_estimators=50 ...........
# [CV]  algorithm=SAMME, learning_rate=0.001, n_estimators=50, total=   1.1s
# [CV] algorithm=SAMME, learning_rate=0.001, n_estimators=100 ..........
# [CV]  algorithm=SAMME, learning_rate=0.001, n_estimators=100, total=   2.2s
# [CV] algorithm=SAMME, learning_rate=0.001, n_estimators=100 ..........
# [CV]  algorithm=SAMME, learning_rate=0.001, n_estimators=100, total=   2.2s
# [CV] algorithm=SAMME, learning_rate=0.001, n_estimators=500 ..........
# [CV]  algorithm=SAMME, learning_rate=0.001, n_estimators=500, total=  11.6s
# [CV] algorithm=SAMME, learning_rate=0.001, n_estimators=500 ..........
# [CV]  algorithm=SAMME, learning_rate=0.001, n_estimators=500, total=  12.3s
# [CV] algorithm=SAMME, learning_rate=0.01, n_estimators=10 ............
# [CV]  algorithm=SAMME, learning_rate=0.01, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME, learning_rate=0.01, n_estimators=10 ............
# [CV]  algorithm=SAMME, learning_rate=0.01, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME, learning_rate=0.01, n_estimators=50 ............
# [CV]  algorithm=SAMME, learning_rate=0.01, n_estimators=50, total=   1.1s
# [CV] algorithm=SAMME, learning_rate=0.01, n_estimators=50 ............
# [CV]  algorithm=SAMME, learning_rate=0.01, n_estimators=50, total=   1.1s
# [CV] algorithm=SAMME, learning_rate=0.01, n_estimators=100 ...........
# [CV]  algorithm=SAMME, learning_rate=0.01, n_estimators=100, total=   2.3s
# [CV] algorithm=SAMME, learning_rate=0.01, n_estimators=100 ...........
# [CV]  algorithm=SAMME, learning_rate=0.01, n_estimators=100, total=   2.2s
# [CV] algorithm=SAMME, learning_rate=0.01, n_estimators=500 ...........
# [CV]  algorithm=SAMME, learning_rate=0.01, n_estimators=500, total=  11.7s
# [CV] algorithm=SAMME, learning_rate=0.01, n_estimators=500 ...........
# [CV]  algorithm=SAMME, learning_rate=0.01, n_estimators=500, total=  12.3s
# [CV] algorithm=SAMME, learning_rate=0.1, n_estimators=10 .............
# [CV]  algorithm=SAMME, learning_rate=0.1, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME, learning_rate=0.1, n_estimators=10 .............
# [CV]  algorithm=SAMME, learning_rate=0.1, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME, learning_rate=0.1, n_estimators=50 .............
# [CV]  algorithm=SAMME, learning_rate=0.1, n_estimators=50, total=   1.5s
# [CV] algorithm=SAMME, learning_rate=0.1, n_estimators=50 .............
# [CV]  algorithm=SAMME, learning_rate=0.1, n_estimators=50, total=   1.1s
# [CV] algorithm=SAMME, learning_rate=0.1, n_estimators=100 ............
# [CV]  algorithm=SAMME, learning_rate=0.1, n_estimators=100, total=   2.3s
# [CV] algorithm=SAMME, learning_rate=0.1, n_estimators=100 ............
# [CV]  algorithm=SAMME, learning_rate=0.1, n_estimators=100, total=   2.3s
# [CV] algorithm=SAMME, learning_rate=0.1, n_estimators=500 ............
# [CV]  algorithm=SAMME, learning_rate=0.1, n_estimators=500, total=  11.5s
# [CV] algorithm=SAMME, learning_rate=0.1, n_estimators=500 ............
# [CV]  algorithm=SAMME, learning_rate=0.1, n_estimators=500, total=  12.0s
# [CV] algorithm=SAMME, learning_rate=1.0, n_estimators=10 .............
# [CV]  algorithm=SAMME, learning_rate=1.0, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME, learning_rate=1.0, n_estimators=10 .............
# [CV]  algorithm=SAMME, learning_rate=1.0, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME, learning_rate=1.0, n_estimators=50 .............
# [CV]  algorithm=SAMME, learning_rate=1.0, n_estimators=50, total=   1.2s
# [CV] algorithm=SAMME, learning_rate=1.0, n_estimators=50 .............
# [CV]  algorithm=SAMME, learning_rate=1.0, n_estimators=50, total=   1.3s
# [CV] algorithm=SAMME, learning_rate=1.0, n_estimators=100 ............
# [CV]  algorithm=SAMME, learning_rate=1.0, n_estimators=100, total=   2.6s
# [CV] algorithm=SAMME, learning_rate=1.0, n_estimators=100 ............
# [CV]  algorithm=SAMME, learning_rate=1.0, n_estimators=100, total=   2.3s
# [CV] algorithm=SAMME, learning_rate=1.0, n_estimators=500 ............
# [CV]  algorithm=SAMME, learning_rate=1.0, n_estimators=500, total=  11.6s
# [CV] algorithm=SAMME, learning_rate=1.0, n_estimators=500 ............
# [CV]  algorithm=SAMME, learning_rate=1.0, n_estimators=500, total=  12.1s
# [CV] algorithm=SAMME.R, learning_rate=0.0001, n_estimators=10 ........
# [CV]  algorithm=SAMME.R, learning_rate=0.0001, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME.R, learning_rate=0.0001, n_estimators=10 ........
# [CV]  algorithm=SAMME.R, learning_rate=0.0001, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME.R, learning_rate=0.0001, n_estimators=50 ........
# [CV]  algorithm=SAMME.R, learning_rate=0.0001, n_estimators=50, total=   1.2s
# [CV] algorithm=SAMME.R, learning_rate=0.0001, n_estimators=50 ........
# [CV]  algorithm=SAMME.R, learning_rate=0.0001, n_estimators=50, total=   1.1s
# [CV] algorithm=SAMME.R, learning_rate=0.0001, n_estimators=100 .......
# [CV]  algorithm=SAMME.R, learning_rate=0.0001, n_estimators=100, total=   2.6s
# [CV] algorithm=SAMME.R, learning_rate=0.0001, n_estimators=100 .......
# [CV]  algorithm=SAMME.R, learning_rate=0.0001, n_estimators=100, total=   2.4s
# [CV] algorithm=SAMME.R, learning_rate=0.0001, n_estimators=500 .......
# [CV]  algorithm=SAMME.R, learning_rate=0.0001, n_estimators=500, total=  12.1s
# [CV] algorithm=SAMME.R, learning_rate=0.0001, n_estimators=500 .......
# [CV]  algorithm=SAMME.R, learning_rate=0.0001, n_estimators=500, total=  12.7s
# [CV] algorithm=SAMME.R, learning_rate=0.001, n_estimators=10 .........
# [CV]  algorithm=SAMME.R, learning_rate=0.001, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME.R, learning_rate=0.001, n_estimators=10 .........
# [CV]  algorithm=SAMME.R, learning_rate=0.001, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME.R, learning_rate=0.001, n_estimators=50 .........
# [CV]  algorithm=SAMME.R, learning_rate=0.001, n_estimators=50, total=   1.2s
# [CV] algorithm=SAMME.R, learning_rate=0.001, n_estimators=50 .........
# [CV]  algorithm=SAMME.R, learning_rate=0.001, n_estimators=50, total=   1.2s
# [CV] algorithm=SAMME.R, learning_rate=0.001, n_estimators=100 ........
# [CV]  algorithm=SAMME.R, learning_rate=0.001, n_estimators=100, total=   2.7s
# [CV] algorithm=SAMME.R, learning_rate=0.001, n_estimators=100 ........
# [CV]  algorithm=SAMME.R, learning_rate=0.001, n_estimators=100, total=   2.3s
# [CV] algorithm=SAMME.R, learning_rate=0.001, n_estimators=500 ........
# [CV]  algorithm=SAMME.R, learning_rate=0.001, n_estimators=500, total=  11.9s
# [CV] algorithm=SAMME.R, learning_rate=0.001, n_estimators=500 ........
# [CV]  algorithm=SAMME.R, learning_rate=0.001, n_estimators=500, total=  12.5s
# [CV] algorithm=SAMME.R, learning_rate=0.01, n_estimators=10 ..........
# [CV]  algorithm=SAMME.R, learning_rate=0.01, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME.R, learning_rate=0.01, n_estimators=10 ..........
# [CV]  algorithm=SAMME.R, learning_rate=0.01, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME.R, learning_rate=0.01, n_estimators=50 ..........
# [CV]  algorithm=SAMME.R, learning_rate=0.01, n_estimators=50, total=   1.2s
# [CV] algorithm=SAMME.R, learning_rate=0.01, n_estimators=50 ..........
# [CV]  algorithm=SAMME.R, learning_rate=0.01, n_estimators=50, total=   1.1s
# [CV] algorithm=SAMME.R, learning_rate=0.01, n_estimators=100 .........
# [CV]  algorithm=SAMME.R, learning_rate=0.01, n_estimators=100, total=   2.4s
# [CV] algorithm=SAMME.R, learning_rate=0.01, n_estimators=100 .........
# [CV]  algorithm=SAMME.R, learning_rate=0.01, n_estimators=100, total=   2.6s
# [CV] algorithm=SAMME.R, learning_rate=0.01, n_estimators=500 .........
# [CV]  algorithm=SAMME.R, learning_rate=0.01, n_estimators=500, total=  12.0s
# [CV] algorithm=SAMME.R, learning_rate=0.01, n_estimators=500 .........
# [CV]  algorithm=SAMME.R, learning_rate=0.01, n_estimators=500, total=  12.6s
# [CV] algorithm=SAMME.R, learning_rate=0.1, n_estimators=10 ...........
# [CV]  algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME.R, learning_rate=0.1, n_estimators=10 ...........
# [CV]  algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME.R, learning_rate=0.1, n_estimators=50 ...........
# [CV]  algorithm=SAMME.R, learning_rate=0.1, n_estimators=50, total=   1.2s
# [CV] algorithm=SAMME.R, learning_rate=0.1, n_estimators=50 ...........
# [CV]  algorithm=SAMME.R, learning_rate=0.1, n_estimators=50, total=   1.2s
# [CV] algorithm=SAMME.R, learning_rate=0.1, n_estimators=100 ..........
# [CV]  algorithm=SAMME.R, learning_rate=0.1, n_estimators=100, total=   2.3s
# [CV] algorithm=SAMME.R, learning_rate=0.1, n_estimators=100 ..........
# [CV]  algorithm=SAMME.R, learning_rate=0.1, n_estimators=100, total=   2.7s
# [CV] algorithm=SAMME.R, learning_rate=0.1, n_estimators=500 ..........
# [CV]  algorithm=SAMME.R, learning_rate=0.1, n_estimators=500, total=  12.1s
# [CV] algorithm=SAMME.R, learning_rate=0.1, n_estimators=500 ..........
# [CV]  algorithm=SAMME.R, learning_rate=0.1, n_estimators=500, total=  12.4s
# [CV] algorithm=SAMME.R, learning_rate=1.0, n_estimators=10 ...........
# [CV]  algorithm=SAMME.R, learning_rate=1.0, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME.R, learning_rate=1.0, n_estimators=10 ...........
# [CV]  algorithm=SAMME.R, learning_rate=1.0, n_estimators=10, total=   0.2s
# [CV] algorithm=SAMME.R, learning_rate=1.0, n_estimators=50 ...........
# [CV]  algorithm=SAMME.R, learning_rate=1.0, n_estimators=50, total=   1.2s
# [CV] algorithm=SAMME.R, learning_rate=1.0, n_estimators=50 ...........
# [CV]  algorithm=SAMME.R, learning_rate=1.0, n_estimators=50, total=   1.2s
# [CV] algorithm=SAMME.R, learning_rate=1.0, n_estimators=100 ..........
# [CV]  algorithm=SAMME.R, learning_rate=1.0, n_estimators=100, total=   2.3s
# [CV] algorithm=SAMME.R, learning_rate=1.0, n_estimators=100 ..........
# [CV]  algorithm=SAMME.R, learning_rate=1.0, n_estimators=100, total=   2.6s
# [CV] algorithm=SAMME.R, learning_rate=1.0, n_estimators=500 ..........
# [CV]  algorithm=SAMME.R, learning_rate=1.0, n_estimators=500, total=  11.9s
# [CV] algorithm=SAMME.R, learning_rate=1.0, n_estimators=500 ..........
# [CV]  algorithm=SAMME.R, learning_rate=1.0, n_estimators=500, total=  12.7s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:  5.3min finished
# Best parameters are:
# {'algorithm': 'SAMME.R', 'learning_rate': 0.1, 'n_estimators': 500}

# %%
ao_train_accuracy, ao_test_accuracy, ao_train_auc, ao_test_auc=check_scores(ada_optimal_model,x_train,x_test, y_train, y_test)
# Out:
# Train confusion matrix is:
# [[6761   94]
#  [1043  757]]
#
# Test confusion matrix is:
# [[2278   45]
#  [ 340  223]]
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      2323
#            1       0.83      0.40      0.54       563
#
#     accuracy                           0.87      2886
#    macro avg       0.85      0.69      0.73      2886
# weighted avg       0.86      0.87      0.85      2886
#
#
# Train accuracy score:  0.868630849220104
# Test accuracy score:  0.8665973665973666
#
# Train ROC-AUC score:  0.9218550936056407
# Test ROC-AUC score:  0.8779339205061136
#
# Are under Precision-Recall curve: 0.5367027677496993
# Area under ROC-AUC: 0.7021179688268547

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:powderblue;
#            color:Black;
#            font-family:cursive
#            ">
# <h1 style="text-align:center;font-weight: bold"> Bagging with MultinomialNB
#  </h1>
# </div>

# %%
kfold = model_selection.KFold(n_splits = 3)
  
# bagging classifier
model = BaggingClassifier(base_estimator = MultinomialNB(),
                          n_estimators = 100)

b_train_accuracy, b_test_accuracy, b_train_auc, b_test_auc= check_scores(model,x_train,x_test, y_train, y_test)
# Out:
# Train confusion matrix is:
# [[6853    2]
#  [1318  482]]
#
# Test confusion matrix is:
# [[2319    4]
#  [ 475   88]]
#
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91      2323
#            1       0.96      0.16      0.27       563
#
#     accuracy                           0.83      2886
#    macro avg       0.89      0.58      0.59      2886
# weighted avg       0.85      0.83      0.78      2886
#
#
# Train accuracy score:  0.8474870017331022
# Test accuracy score:  0.834026334026334
#
# Train ROC-AUC score:  0.9525061188102764
# Test ROC-AUC score:  0.8998424130002777
#
# Are under Precision-Recall curve: 0.2687022900763359
# Area under ROC-AUC: 0.7345749814146296

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:powderblue;
#            color:Black;
#            font-family:cursive
#            ">
# <h1 style="text-align:center;font-weight: bold">Using Random Forest
#  </h1>
# </div>

# %%
r_train_accuracy, r_test_accuracy, r_train_auc, r_test_auc= check_scores(RandomForestClassifier(random_state=0).fit(x_train, y_train), x_train,x_test,y_train,y_test)
# Out:
# Train confusion matrix is:
# [[6829   26]
#  [   5 1795]]
#
# Test confusion matrix is:
# [[2215  108]
#  [ 238  325]]
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93      2323
#            1       0.75      0.58      0.65       563
#
#     accuracy                           0.88      2886
#    macro avg       0.83      0.77      0.79      2886
# weighted avg       0.87      0.88      0.87      2886
#
#
# Train accuracy score:  0.996418255343732
# Test accuracy score:  0.8801108801108801
#
# Train ROC-AUC score:  0.9982442661479861
# Test ROC-AUC score:  0.8956867344777572
#
# Are under Precision-Recall curve: 0.6526104417670683
# Area under ROC-AUC: 0.7441899264879837

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:powderblue;
#            color:Black;
#            font-family:cursive
#            ">
# <h1 style="text-align:center;font-weight: bold">Using LSTM
#  </h1>
# </div>

# %%
corpus = [df['cleaned_tweet'][i] for i in range( len(df))]

voc_size=5000

onehot_=[one_hot(words,voc_size)for words in corpus] 

max_sent_length=max([len(i) for i in corpus])

embedded_docs=pad_sequences(onehot_,padding='pre',maxlen=max_sent_length)
    
embedding_vector_features=40
model=Sequential()
model.add(Embedding(voc_size,embedding_vector_features,input_length=max_sent_length))
model.add(Dropout(0.3))
model.add(LSTM(100))
model.add(Dropout(0.3))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

X_final=np.array(embedded_docs)
y_final=np.array(df['airline_sentiment'])
X_final.shape,y_final.shape
# Out:
# 2022-01-06 07:32:36.602285: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-01-06 07:32:36.606309: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-01-06 07:32:36.657305: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 07:32:36.658367: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2022-01-06 07:32:36.658482: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-01-06 07:32:36.685884: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-01-06 07:32:36.686073: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-01-06 07:32:36.708032: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-01-06 07:32:36.716806: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-01-06 07:32:36.741650: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-01-06 07:32:36.748864: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-01-06 07:32:36.752676: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-01-06 07:32:36.752918: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 07:32:36.753983: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 07:32:36.755817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-01-06 07:32:36.757898: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-06 07:32:36.758164: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-01-06 07:32:36.758412: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 07:32:36.759322: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2022-01-06 07:32:36.759425: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-01-06 07:32:36.759471: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-01-06 07:32:36.759506: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-01-06 07:32:36.759540: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-01-06 07:32:36.759576: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-01-06 07:32:36.759612: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-01-06 07:32:36.759648: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-01-06 07:32:36.759685: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-01-06 07:32:36.759806: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 07:32:36.760845: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 07:32:36.761750: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-01-06 07:32:36.763126: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-01-06 07:32:38.247897: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-01-06 07:32:38.247944: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-01-06 07:32:38.247954: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-01-06 07:32:38.250100: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 07:32:38.250843: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 07:32:38.251488: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-06 07:32:38.252040: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14957 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# ((11541, 124), (11541,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size=0.33, random_state=42)
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=10,batch_size=64)
# Out:
# 2022-01-06 07:32:38.903020: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-01-06 07:32:38.913133: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2000170000 Hz
# Epoch 1/10
# 2022-01-06 07:32:40.600036: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-01-06 07:32:41.447746: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-01-06 07:32:41.501725: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 121/121 [==============================] - 10s 19ms/step - loss: 0.5460 - accuracy: 0.7747 - val_loss: 0.3390 - val_accuracy: 0.8519
# Epoch 2/10
# 121/121 [==============================] - 2s 13ms/step - loss: 0.2935 - accuracy: 0.8775 - val_loss: 0.2888 - val_accuracy: 0.8892
# Epoch 3/10
# 121/121 [==============================] - 2s 14ms/step - loss: 0.1997 - accuracy: 0.9193 - val_loss: 0.2902 - val_accuracy: 0.8887
# Epoch 4/10
# 121/121 [==============================] - 2s 14ms/step - loss: 0.1589 - accuracy: 0.9391 - val_loss: 0.3124 - val_accuracy: 0.8792
# Epoch 5/10
# 121/121 [==============================] - 2s 13ms/step - loss: 0.1253 - accuracy: 0.9549 - val_loss: 0.3389 - val_accuracy: 0.8779
# Epoch 6/10
# 121/121 [==============================] - 2s 13ms/step - loss: 0.1113 - accuracy: 0.9613 - val_loss: 0.3745 - val_accuracy: 0.8769
# Epoch 7/10
# 121/121 [==============================] - 2s 13ms/step - loss: 0.0898 - accuracy: 0.9671 - val_loss: 0.3949 - val_accuracy: 0.8711
# Epoch 8/10
# 121/121 [==============================] - 2s 13ms/step - loss: 0.0858 - accuracy: 0.9694 - val_loss: 0.4239 - val_accuracy: 0.8703
# Epoch 9/10
# 121/121 [==============================] - 2s 13ms/step - loss: 0.0758 - accuracy: 0.9712 - val_loss: 0.4847 - val_accuracy: 0.8658
# Epoch 10/10
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0651 - accuracy: 0.9763 - val_loss: 0.5238 - val_accuracy: 0.8635

# %%
y_test_pred=model.predict_classes(X_test)
y_train_pred=model.predict_classes(X_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
test_acc_lstm = accuracy_score(y_test,y_test_pred)
train_acc_lstm = accuracy_score(y_train,y_train_pred)
test_roc_lstm = roc_auc_score(y_test,y_test_pred)
train_roc_lstm = roc_auc_score(y_train,y_train_pred)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:powderblue;
#            color:Black;
#            font-family:cursive
#            ">
# <h1 style="text-align:center;font-weight: bold">Final Results
#  </h1>
# </div>

# %%
data = [('Random Forest', r_train_accuracy, r_test_accuracy, r_train_auc, r_test_auc),
 ('MultinomialNB',m_train_accuracy, m_test_accuracy, m_train_auc, m_test_auc  ),
('Bagged MultinomialNB',b_train_accuracy, b_test_accuracy, b_train_auc, b_test_auc ),
 ('AdaBoost',a_train_accuracy, a_test_accuracy, a_train_auc, a_test_auc ),
('AdaBoost Optimized',ao_train_accuracy, ao_test_accuracy, ao_train_auc, ao_test_auc),
('Gaussian Naive Bayes',g_train_accuracy, g_test_accuracy, g_train_auc, g_test_auc),
('SVM', s_train_accuracy, s_test_accuracy, s_train_auc, s_test_auc),
('SVM Optimized', so_train_accuracy, so_test_accuracy, so_train_auc, so_test_auc),
('LSTM',train_acc_lstm, test_acc_lstm, train_roc_lstm, test_roc_lstm )]


Scores_ =pd.DataFrame(data = data, columns=['Model Name','Train Accuracy', 'Test Accuracy', 'Train ROC', 'Test ROC'])
Scores_.set_index('Model Name', inplace = True)

Scores_
# Out:
#                       Train Accuracy  Test Accuracy  Train ROC  Test ROC
# Model Name
# Random Forest               0.996418       0.880111   0.998244  0.895687
# MultinomialNB               0.850029       0.834026   0.956111  0.901301
# Bagged MultinomialNB        0.847487       0.834026   0.952506  0.899842
# AdaBoost                    0.859965       0.861400   0.868948  0.837380
# AdaBoost Optimized          0.868631       0.866597   0.921855  0.877934
# Gaussian Naive Bayes        0.848411       0.694733   0.904303  0.688587
# SVM                         0.978972       0.886348   0.996906  0.929177
# SVM Optimized               0.996418       0.897436   0.998731  0.928743
# LSTM                        0.984868       0.863481   0.980694  0.787352

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            font-size:110%;
#            font-family:cursive;
#            letter-spacing:0.5px;
#            background-color:powderblue;
#            color:Black;
#            font-family:cursive
#            ">
# <h1 style="text-align:center;font-weight: bold">Conclusion
#  </h1>
# </div>
#
# **Most of the models are doing pretty well here.**
